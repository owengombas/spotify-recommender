# %% [markdown]
# # Documentation
# **Best grade**
# - Report
# - Can I redo everything ?
# - No ambiguity
#
# **Passing grade**
# - High level idea

# %% [markdown]
# # Technical
# **Best grade**
# - No major errors
#
# **Passing grade**
# - Error not seriously impacting the result

# %% [markdown]
# # Analysis
# **Best grade**
# - Explain why we used this method
# - Justify
# - Criteria to determine the best model (define a metric)
#
# **Passing grade**
# - Indiquate justifications -> Too simple / Too complex

# %% [markdown]
# # Reproducibility
# **Best grade**
# - Testing procedure
# - Unbiased measurements
#
# **Passing grade**
# - Possible biased model model selection

# %% [markdown]
# # Science / Ethics
# **Best grade**
# - Scientific question
# - Ethical concerns
#
# **Passing grade**
# - Barely mentionned

# %% [markdown]
# # Research
