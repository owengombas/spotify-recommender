# %%
import pandas as pd
from lib import spoti
from constants import data_path, users_list
import os

# %%
[u.get_auth_url() for u in users_list.USERS]
# Out:
# ['https://accounts.spotify.com/authorize?client_id=a75393ab40f14735bc524677cb4ce3b7&response_type=code&redirect_uri=https%3A%2F%2Fgithub.com%2Fowengombas&scope=user-library-read+user-read-currently-playing+user-read-playback-state+playlist-read-collaborative+user-top-read+user-read-recently-played+user-library-read+user-read-email+']

# %%
[u.log_user() for u in users_list.USERS]
# Out:
# [None]

# %%
df_playlists = pd.DataFrame()
for u in users_list.USERS:
    df_playlist = u.get_playlists()
    df_playlist.to_json(os.path.join(data_path.DATA_PATH, f"{u.username}_playlists.json"), orient="records")
    df_playlists = pd.concat([df_playlists, df_playlist])
df_playlists
# Out:
#    collaborative description  \
# 0          False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/674vFKUXN...  674vFKUXNUjlUxXhAnQvG9
#
#                                               images   name  \
# 0  [{'height': None, 'url': 'https://image-cdn-ak...  P. F.
#
#                                                owner primary_color  public  \
# 0  {'display_name': 'danydacosta', 'external_urls...          None    True
#
#                                          snapshot_id  \
# 0  NzIsZGViNzE2MmQ0YWEzMWY0NmMyZDY5ZmMzNDkyNGM5OD...
#
#                                               tracks      type  \
# 0  {'href': 'https://api.spotify.com/v1/playlists...  playlist
#
#                                        uri username
# 0  spotify:playlist:674vFKUXNUjlUxXhAnQvG9     dany

# %%
all_user_playlists_tracks = pd.DataFrame()
for user in users_list.USERS:
    df_playlists_tracks = pd.DataFrame()
    for playlist_id in df_playlists[df_playlists["username"] == user.username]["id"]:
        df_current_playlist_tracks = user.get_playlist_tracks(playlist_id)
        df_playlists_tracks = pd.concat([df_playlists_tracks, df_current_playlist_tracks])
    df_playlists_tracks.to_json(os.path.join(data_path.DATA_PATH, f"{user.username}_playlists_tracks.json"), orient="records")
    all_user_playlists_tracks = pd.concat([all_user_playlists_tracks, df_playlists_tracks])
all_user_playlists_tracks
# Out:
#                                                 album  \
# 0   {'album_type': 'album', 'artists': [{'external...
# 1   {'album_type': 'album', 'artists': [{'external...
# 2   {'album_type': 'album', 'artists': [{'external...
# 3   {'album_type': 'album', 'artists': [{'external...
# 4   {'album_type': 'album', 'artists': [{'external...
# 5   {'album_type': 'album', 'artists': [{'external...
# 6   {'album_type': 'album', 'artists': [{'external...
# 7   {'album_type': 'album', 'artists': [{'external...
# 8   {'album_type': 'album', 'artists': [{'external...
# 9   {'album_type': 'album', 'artists': [{'external...
# 10  {'album_type': 'album', 'artists': [{'external...
# 11  {'album_type': 'album', 'artists': [{'external...
# 12  {'album_type': 'album', 'artists': [{'external...
# 13  {'album_type': 'album', 'artists': [{'external...
# 14  {'album_type': 'album', 'artists': [{'external...
# 15  {'album_type': 'album', 'artists': [{'external...
# 16  {'album_type': 'album', 'artists': [{'external...
# 17  {'album_type': 'album', 'artists': [{'external...
# 18  {'album_type': 'album', 'artists': [{'external...
# 19  {'album_type': 'album', 'artists': [{'external...
# 20  {'album_type': 'album', 'artists': [{'external...
# 21  {'album_type': 'album', 'artists': [{'external...
# 22  {'album_type': 'album', 'artists': [{'external...
# 23  {'album_type': 'album', 'artists': [{'external...
# 24  {'album_type': 'album', 'artists': [{'external...
# 25  {'album_type': 'album', 'artists': [{'external...
# 26  {'album_type': 'album', 'artists': [{'external...
# 27  {'album_type': 'album', 'artists': [{'external...
# 28  {'album_type': 'album', 'artists': [{'external...
# 29  {'album_type': 'album', 'artists': [{'external...
# 30  {'album_type': 'album', 'artists': [{'external...
# 31  {'album_type': 'album', 'artists': [{'external...
# 32  {'album_type': 'album', 'artists': [{'external...
# 33  {'album_type': 'album', 'artists': [{'external...
# 34  {'album_type': 'album', 'artists': [{'external...
# 35  {'album_type': 'album', 'artists': [{'external...
# 36  {'album_type': 'album', 'artists': [{'external...
# 37  {'album_type': 'album', 'artists': [{'external...
# 38  {'album_type': 'album', 'artists': [{'external...
# 39  {'album_type': 'album', 'artists': [{'external...
# 40  {'album_type': 'album', 'artists': [{'external...
# 41  {'album_type': 'album', 'artists': [{'external...
#
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 25  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 32  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 34  [{'external_urls': {'spotify': 'https://open.s...
# 35  [{'external_urls': {'spotify': 'https://open.s...
# 36  [{'external_urls': {'spotify': 'https://open.s...
# 37  [{'external_urls': {'spotify': 'https://open.s...
# 38  [{'external_urls': {'spotify': 'https://open.s...
# 39  [{'external_urls': {'spotify': 'https://open.s...
# 40  [{'external_urls': {'spotify': 'https://open.s...
# 41  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 1   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 2   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 3   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 4   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 5   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 6   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 7   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 8   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 9   [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 10  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 11  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 12  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 13  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 14  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 15  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 16  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 17  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 18  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 19  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 20  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            2
# 21  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            2
# 22  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 23  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 24  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 25  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 26  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 27  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 28  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 29  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 30  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 31  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 32  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 33  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 34  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 35  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 36  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
# 37  [AD, AL, AM, AT, AZ, BA, BE, BG, BY, CH, CW, C...            1
# 38  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 39  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 40  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 41  [AD, AL, AM, AT, AZ, BA, BE, BG, CH, CW, CY, C...            1
#
#     duration_ms  episode  explicit              external_ids  \
# 0       1421720    False     False  {'isrc': 'GBN9Y1100173'}
# 1        323946    False     False  {'isrc': 'GBN9Y1100056'}
# 2        355400    False     False  {'isrc': 'GBN9Y1100060'}
# 3       1413306    False     False  {'isrc': 'GBN9Y1100065'}
# 4        169560    False     False  {'isrc': 'GBN9Y1100077'}
# 5        422853    False     False  {'isrc': 'GBN9Y1100079'}
# 6        284413    False     False  {'isrc': 'GBN9Y1100080'}
# 7        225826    False     False  {'isrc': 'GBN9Y1100140'}
# 8        114093    False     False  {'isrc': 'GBN9Y1100084'}
# 9        810293    False     False  {'isrc': 'GBN9Y1100085'}
# 10       307440    False     False  {'isrc': 'GBN9Y1100087'}
# 11       743986    False     False  {'isrc': 'GBN9Y1100089'}
# 12       304200    False     False  {'isrc': 'GBN9Y1100088'}
# 13       379213    False     False  {'isrc': 'GBN9Y1100113'}
# 14       278706    False     False  {'isrc': 'GBN9Y1100108'}
# 15       255906    False     False  {'isrc': 'GBN9Y1100115'}
# 16       292080    False     False  {'isrc': 'GBN9X1100002'}
# 17       308666    False     False  {'isrc': 'GBN9X1100004'}
# 18       341666    False     False  {'isrc': 'GBN9X1100005'}
# 19       524753    False     False  {'isrc': 'GBN9X1100011'}
# 20       153600    False     False  {'isrc': 'GBDJQ9400079'}
# 21       201066    False     False  {'isrc': 'GBDJQ9400073'}
# 22       257613    False     False  {'isrc': 'GBN9X1100016'}
# 23       329360    False     False  {'isrc': 'GBN9X1100015'}
# 24       408866    False     False  {'isrc': 'GBN9X1100017'}
# 25       372400    False     False  {'isrc': 'GBN9X1100018'}
# 26       379280    False     False  {'isrc': 'GBN9X1100019'}
# 27       511013    False     False  {'isrc': 'GBN9X1100022'}
# 28       355493    False     False  {'isrc': 'GBN9X1100012'}
# 29       261480    False     False  {'isrc': 'GBN9X1100013'}
# 30       423693    False     False  {'isrc': 'GBN9X1100014'}
# 31       314666    False      True  {'isrc': 'GBN9X1100021'}
# 32       264600    False     False  {'isrc': 'GBN9X1400051'}
# 33       392573    False     False  {'isrc': 'GBN9X1400068'}
# 34       273693    False     False  {'isrc': 'GBN9Y1100072'}
# 35       330733    False     False  {'isrc': 'GBN9X1400200'}
# 36      1026853    False     False  {'isrc': 'GBN9Y1800013'}
# 37       251880    False     False  {'isrc': 'GBN9Y1100001'}
# 38       193853    False     False  {'isrc': 'GBLTP1700005'}
# 39       295493    False     False  {'isrc': 'GBLTP1700011'}
# 40       467306    False     False  {'isrc': 'GBLTP1700014'}
# 41       233760    False     False  {'isrc': 'GBLTP0600001'}
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/track/3I...
# 1   {'spotify': 'https://open.spotify.com/track/0Y...
# 2   {'spotify': 'https://open.spotify.com/track/0G...
# 3   {'spotify': 'https://open.spotify.com/track/1M...
# 4   {'spotify': 'https://open.spotify.com/track/3z...
# 5   {'spotify': 'https://open.spotify.com/track/4x...
# 6   {'spotify': 'https://open.spotify.com/track/25...
# 7   {'spotify': 'https://open.spotify.com/track/7E...
# 8   {'spotify': 'https://open.spotify.com/track/3Z...
# 9   {'spotify': 'https://open.spotify.com/track/32...
# 10  {'spotify': 'https://open.spotify.com/track/5n...
# 11  {'spotify': 'https://open.spotify.com/track/2Y...
# 12  {'spotify': 'https://open.spotify.com/track/7a...
# 13  {'spotify': 'https://open.spotify.com/track/7F...
# 14  {'spotify': 'https://open.spotify.com/track/5U...
# 15  {'spotify': 'https://open.spotify.com/track/0B...
# 16  {'spotify': 'https://open.spotify.com/track/50...
# 17  {'spotify': 'https://open.spotify.com/track/52...
# 18  {'spotify': 'https://open.spotify.com/track/0R...
# 19  {'spotify': 'https://open.spotify.com/track/2m...
# 20  {'spotify': 'https://open.spotify.com/track/6r...
# 21  {'spotify': 'https://open.spotify.com/track/2O...
# 22  {'spotify': 'https://open.spotify.com/track/0C...
# 23  {'spotify': 'https://open.spotify.com/track/5k...
# 24  {'spotify': 'https://open.spotify.com/track/17...
# 25  {'spotify': 'https://open.spotify.com/track/6A...
# 26  {'spotify': 'https://open.spotify.com/track/0n...
# 27  {'spotify': 'https://open.spotify.com/track/23...
# 28  {'spotify': 'https://open.spotify.com/track/7b...
# 29  {'spotify': 'https://open.spotify.com/track/6O...
# 30  {'spotify': 'https://open.spotify.com/track/2o...
# 31  {'spotify': 'https://open.spotify.com/track/7v...
# 32  {'spotify': 'https://open.spotify.com/track/48...
# 33  {'spotify': 'https://open.spotify.com/track/6F...
# 34  {'spotify': 'https://open.spotify.com/track/4u...
# 35  {'spotify': 'https://open.spotify.com/track/16...
# 36  {'spotify': 'https://open.spotify.com/track/71...
# 37  {'spotify': 'https://open.spotify.com/track/3z...
# 38  {'spotify': 'https://open.spotify.com/track/1V...
# 39  {'spotify': 'https://open.spotify.com/track/0K...
# 40  {'spotify': 'https://open.spotify.com/track/6v...
# 41  {'spotify': 'https://open.spotify.com/track/0Y...
#
#                                                  href  ... instrumentalness  \
# 0   https://api.spotify.com/v1/tracks/3IhsfUBlbcT1...  ...         0.847000
# 1   https://api.spotify.com/v1/tracks/0YNaC18YzZHB...  ...         0.652000
# 2   https://api.spotify.com/v1/tracks/0Ga3szKsJOeZ...  ...         0.855000
# 3   https://api.spotify.com/v1/tracks/1Mzm1CNqVxtw...  ...         0.574000
# 4   https://api.spotify.com/v1/tracks/3zJRvtQkHQRT...  ...         0.184000
# 5   https://api.spotify.com/v1/tracks/4xHWH1jwV5j4...  ...         0.002250
# 6   https://api.spotify.com/v1/tracks/25tZHMv3ctlz...  ...         0.739000
# 7   https://api.spotify.com/v1/tracks/7EUEl5wJb8VI...  ...         0.181000
# 8   https://api.spotify.com/v1/tracks/3Z2RsIdWm4BN...  ...         0.841000
# 9   https://api.spotify.com/v1/tracks/32dnKMni3I3g...  ...         0.661000
# 10  https://api.spotify.com/v1/tracks/5nfMtk9Zty1A...  ...         0.009440
# 11  https://api.spotify.com/v1/tracks/2YMN5C5XDSsq...  ...         0.888000
# 12  https://api.spotify.com/v1/tracks/7aE5WXu5sFeN...  ...         0.000746
# 13  https://api.spotify.com/v1/tracks/7Fg4jpwpkdkG...  ...         0.220000
# 14  https://api.spotify.com/v1/tracks/5UJmwdqGP7RO...  ...         0.004540
# 15  https://api.spotify.com/v1/tracks/0B545eDyCppa...  ...         0.394000
# 16  https://api.spotify.com/v1/tracks/50MzABA1g2Ks...  ...         0.029600
# 17  https://api.spotify.com/v1/tracks/52kX0pMAjMQv...  ...         0.013100
# 18  https://api.spotify.com/v1/tracks/0R797G9o4tkD...  ...         0.000746
# 19  https://api.spotify.com/v1/tracks/2mETOGyRPsBS...  ...         0.386000
# 20  https://api.spotify.com/v1/tracks/6rDcGOVNd4Kc...  ...         0.000018
# 21  https://api.spotify.com/v1/tracks/2OlMy6bbwn1B...  ...         0.944000
# 22  https://api.spotify.com/v1/tracks/0CT0tNJzauc6...  ...         0.000995
# 23  https://api.spotify.com/v1/tracks/5kLg9cdm7Lay...  ...         0.634000
# 24  https://api.spotify.com/v1/tracks/17Ao8wmdVQ0q...  ...         0.030700
# 25  https://api.spotify.com/v1/tracks/6ATouqjf03zP...  ...         0.005090
# 26  https://api.spotify.com/v1/tracks/0nZVzNtcrXnx...  ...         0.000975
# 27  https://api.spotify.com/v1/tracks/236mI0lz8JdQ...  ...         0.149000
# 28  https://api.spotify.com/v1/tracks/7bi7h1TmrwxN...  ...         0.925000
# 29  https://api.spotify.com/v1/tracks/6O5w78nzFazf...  ...         0.000027
# 30  https://api.spotify.com/v1/tracks/2oiJkWxuZcpc...  ...         0.049300
# 31  https://api.spotify.com/v1/tracks/7vQNnWSr6yXU...  ...         0.005350
# 32  https://api.spotify.com/v1/tracks/489fYYMIvUjY...  ...         0.911000
# 33  https://api.spotify.com/v1/tracks/6FOHrTobTT0Y...  ...         0.000056
# 34  https://api.spotify.com/v1/tracks/4uxrLzUlWG71...  ...         0.000046
# 35  https://api.spotify.com/v1/tracks/16KX9LfZCjRP...  ...         0.928000
# 36  https://api.spotify.com/v1/tracks/715b4AT3ynJy...  ...         0.000187
# 37  https://api.spotify.com/v1/tracks/3z7dWKRsjDNM...  ...         0.667000
# 38  https://api.spotify.com/v1/tracks/1VofMhhL98pe...  ...         0.225000
# 39  https://api.spotify.com/v1/tracks/0KE7apgczHNY...  ...         0.019300
# 40  https://api.spotify.com/v1/tracks/6vbRA9yAAgIX...  ...         0.000936
# 41  https://api.spotify.com/v1/tracks/0YFt5l6xOLbJ...  ...         0.859000
#
#     liveness valence    tempo   type_features  \
# 0     0.0825  0.0872  137.430  audio_features
# 1     0.3890  0.2000   72.840  audio_features
# 2     0.4870  0.3940  103.685  audio_features
# 3     0.1170  0.1390  146.950  audio_features
# 4     0.1570  0.3130  128.455  audio_features
# 5     0.1630  0.3690  122.473  audio_features
# 6     0.0774  0.1680  115.227  audio_features
# 7     0.4310  0.2590  133.708  audio_features
# 8     0.0927  0.1440  135.336  audio_features
# 9     0.1170  0.0445  135.869  audio_features
# 10    0.2320  0.6730  120.107  audio_features
# 11    0.2340  0.1420  135.528  audio_features
# 12    0.2730  0.2930  121.002  audio_features
# 13    0.1340  0.1820  127.155  audio_features
# 14    0.1420  0.2200  112.452  audio_features
# 15    0.5270  0.1260  151.068  audio_features
# 16    0.1510  0.4760  166.585  audio_features
# 17    0.0806  0.3450  117.317  audio_features
# 18    0.0760  0.2440  100.411  audio_features
# 19    0.0728  0.1490   96.303  audio_features
# 20    0.7890  0.2990  124.081  audio_features
# 21    0.3090  0.7170  142.216  audio_features
# 22    0.2270  0.2240   84.581  audio_features
# 23    0.1230  0.1530   74.247  audio_features
# 24    0.1050  0.3600  122.395  audio_features
# 25    0.2370  0.1460  112.427  audio_features
# 26    0.0992  0.1630  176.399  audio_features
# 27    0.3620  0.2380   75.221  audio_features
# 28    0.1250  0.0322   53.957  audio_features
# 29    0.1220  0.3700  104.342  audio_features
# 30    0.6840  0.2650   62.441  audio_features
# 31    0.7180  0.1960   96.296  audio_features
# 32    0.1760  0.0323   85.212  audio_features
# 33    0.0838  0.1160  112.984  audio_features
# 34    0.0934  0.2020  125.041  audio_features
# 35    0.1230  0.4720  208.093  audio_features
# 36    0.1620  0.1700  130.108  audio_features
# 37    0.3190  0.0848  123.610  audio_features
# 38    0.5120  0.1460  146.048  audio_features
# 39    0.8050  0.1410   73.980  audio_features
# 40    0.9590  0.0536  104.068  audio_features
# 41    0.1430  0.0398  112.085  audio_features
#
#                             uri_features  \
# 0   spotify:track:3IhsfUBlbcT11iXxgDt3CW
# 1   spotify:track:0YNaC18YzZHB610787YKud
# 2   spotify:track:0Ga3szKsJOeZ0eAfydm1WV
# 3   spotify:track:1Mzm1CNqVxtwbCYhOo843s
# 4   spotify:track:3zJRvtQkHQRTNEXSY8jQPR
# 5   spotify:track:4xHWH1jwV5j4mBYRhxPbwZ
# 6   spotify:track:25tZHMv3ctlzqDaHAeuU9c
# 7   spotify:track:7EUEl5wJb8VI777UAUvRnH
# 8   spotify:track:3Z2RsIdWm4BNbT0LsFBuoN
# 9   spotify:track:32dnKMni3I3gwUbWp4mi45
# 10  spotify:track:5nfMtk9Zty1AITVo4YDhbb
# 11  spotify:track:2YMN5C5XDSsqCHSoJIbOzj
# 12  spotify:track:7aE5WXu5sFeNRh3Z05wwu4
# 13  spotify:track:7Fg4jpwpkdkGCvq1rrXnvx
# 14  spotify:track:5UJmwdqGP7RONuVzYnHjUp
# 15  spotify:track:0B545eDyCppapUQ1ujrTmg
# 16  spotify:track:50MzABA1g2Ks2KWRA09TOe
# 17  spotify:track:52kX0pMAjMQv7gR2fZ4vwR
# 18  spotify:track:0R797G9o4tkDfRZj6KMnHS
# 19  spotify:track:2mETOGyRPsBSiIybp6SN7k
# 20  spotify:track:6rDcGOVNd4KcC6iNxbKCQI
# 21  spotify:track:2OlMy6bbwn1ByYN6dEi7tM
# 22  spotify:track:0CT0tNJzauc6I4LUg9ESPw
# 23  spotify:track:5kLg9cdm7LayfkyaxVZKdD
# 24  spotify:track:17Ao8wmdVQ0qyaHvBOjftl
# 25  spotify:track:6ATouqjf03zPCRCwE892UN
# 26  spotify:track:0nZVzNtcrXnxVaXiB5bfO4
# 27  spotify:track:236mI0lz8JdQjlmijARSwY
# 28  spotify:track:7bi7h1TmrwxNsf1nqaNtSi
# 29  spotify:track:6O5w78nzFazfs1W8DQHMeQ
# 30  spotify:track:2oiJkWxuZcpcJcS88HjnzG
# 31  spotify:track:7vQNnWSr6yXUJYrA3HoSl0
# 32  spotify:track:489fYYMIvUjY3KwKR4Wox0
# 33  spotify:track:6FOHrTobTT0YXQtQFT4zjk
# 34  spotify:track:4uxrLzUlWG71UR4jN1G4cL
# 35  spotify:track:16KX9LfZCjRPdX84PX1XF9
# 36  spotify:track:715b4AT3ynJyYmtFucyzDu
# 37  spotify:track:3z7dWKRsjDNM24ohLKZBnA
# 38  spotify:track:1VofMhhL98pewltVGBSmCW
# 39  spotify:track:0KE7apgczHNYiXIvMUY0Fc
# 40  spotify:track:6vbRA9yAAgIXtDlmhyNqPq
# 41  spotify:track:0YFt5l6xOLbJSJvyVZDpvX
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3IhsfUBlbcT1...
# 1   https://api.spotify.com/v1/tracks/0YNaC18YzZHB...
# 2   https://api.spotify.com/v1/tracks/0Ga3szKsJOeZ...
# 3   https://api.spotify.com/v1/tracks/1Mzm1CNqVxtw...
# 4   https://api.spotify.com/v1/tracks/3zJRvtQkHQRT...
# 5   https://api.spotify.com/v1/tracks/4xHWH1jwV5j4...
# 6   https://api.spotify.com/v1/tracks/25tZHMv3ctlz...
# 7   https://api.spotify.com/v1/tracks/7EUEl5wJb8VI...
# 8   https://api.spotify.com/v1/tracks/3Z2RsIdWm4BN...
# 9   https://api.spotify.com/v1/tracks/32dnKMni3I3g...
# 10  https://api.spotify.com/v1/tracks/5nfMtk9Zty1A...
# 11  https://api.spotify.com/v1/tracks/2YMN5C5XDSsq...
# 12  https://api.spotify.com/v1/tracks/7aE5WXu5sFeN...
# 13  https://api.spotify.com/v1/tracks/7Fg4jpwpkdkG...
# 14  https://api.spotify.com/v1/tracks/5UJmwdqGP7RO...
# 15  https://api.spotify.com/v1/tracks/0B545eDyCppa...
# 16  https://api.spotify.com/v1/tracks/50MzABA1g2Ks...
# 17  https://api.spotify.com/v1/tracks/52kX0pMAjMQv...
# 18  https://api.spotify.com/v1/tracks/0R797G9o4tkD...
# 19  https://api.spotify.com/v1/tracks/2mETOGyRPsBS...
# 20  https://api.spotify.com/v1/tracks/6rDcGOVNd4Kc...
# 21  https://api.spotify.com/v1/tracks/2OlMy6bbwn1B...
# 22  https://api.spotify.com/v1/tracks/0CT0tNJzauc6...
# 23  https://api.spotify.com/v1/tracks/5kLg9cdm7Lay...
# 24  https://api.spotify.com/v1/tracks/17Ao8wmdVQ0q...
# 25  https://api.spotify.com/v1/tracks/6ATouqjf03zP...
# 26  https://api.spotify.com/v1/tracks/0nZVzNtcrXnx...
# 27  https://api.spotify.com/v1/tracks/236mI0lz8JdQ...
# 28  https://api.spotify.com/v1/tracks/7bi7h1TmrwxN...
# 29  https://api.spotify.com/v1/tracks/6O5w78nzFazf...
# 30  https://api.spotify.com/v1/tracks/2oiJkWxuZcpc...
# 31  https://api.spotify.com/v1/tracks/7vQNnWSr6yXU...
# 32  https://api.spotify.com/v1/tracks/489fYYMIvUjY...
# 33  https://api.spotify.com/v1/tracks/6FOHrTobTT0Y...
# 34  https://api.spotify.com/v1/tracks/4uxrLzUlWG71...
# 35  https://api.spotify.com/v1/tracks/16KX9LfZCjRP...
# 36  https://api.spotify.com/v1/tracks/715b4AT3ynJy...
# 37  https://api.spotify.com/v1/tracks/3z7dWKRsjDNM...
# 38  https://api.spotify.com/v1/tracks/1VofMhhL98pe...
# 39  https://api.spotify.com/v1/tracks/0KE7apgczHNY...
# 40  https://api.spotify.com/v1/tracks/6vbRA9yAAgIX...
# 41  https://api.spotify.com/v1/tracks/0YFt5l6xOLbJ...
#
#                                          analysis_url duration_ms_features  \
# 0   https://api.spotify.com/v1/audio-analysis/3Ihs...              1421720
# 1   https://api.spotify.com/v1/audio-analysis/0YNa...               323947
# 2   https://api.spotify.com/v1/audio-analysis/0Ga3...               355400
# 3   https://api.spotify.com/v1/audio-analysis/1Mzm...              1413307
# 4   https://api.spotify.com/v1/audio-analysis/3zJR...               169560
# 5   https://api.spotify.com/v1/audio-analysis/4xHW...               422853
# 6   https://api.spotify.com/v1/audio-analysis/25tZ...               284413
# 7   https://api.spotify.com/v1/audio-analysis/7EUE...               225827
# 8   https://api.spotify.com/v1/audio-analysis/3Z2R...               114093
# 9   https://api.spotify.com/v1/audio-analysis/32dn...               810293
# 10  https://api.spotify.com/v1/audio-analysis/5nfM...               307440
# 11  https://api.spotify.com/v1/audio-analysis/2YMN...               743987
# 12  https://api.spotify.com/v1/audio-analysis/7aE5...               304200
# 13  https://api.spotify.com/v1/audio-analysis/7Fg4...               379213
# 14  https://api.spotify.com/v1/audio-analysis/5UJm...               278707
# 15  https://api.spotify.com/v1/audio-analysis/0B54...               255907
# 16  https://api.spotify.com/v1/audio-analysis/50Mz...               292080
# 17  https://api.spotify.com/v1/audio-analysis/52kX...               308666
# 18  https://api.spotify.com/v1/audio-analysis/0R79...               341667
# 19  https://api.spotify.com/v1/audio-analysis/2mET...               524753
# 20  https://api.spotify.com/v1/audio-analysis/6rDc...               153600
# 21  https://api.spotify.com/v1/audio-analysis/2OlM...               201067
# 22  https://api.spotify.com/v1/audio-analysis/0CT0...               257613
# 23  https://api.spotify.com/v1/audio-analysis/5kLg...               329360
# 24  https://api.spotify.com/v1/audio-analysis/17Ao...               408867
# 25  https://api.spotify.com/v1/audio-analysis/6ATo...               372400
# 26  https://api.spotify.com/v1/audio-analysis/0nZV...               379280
# 27  https://api.spotify.com/v1/audio-analysis/236m...               511013
# 28  https://api.spotify.com/v1/audio-analysis/7bi7...               355493
# 29  https://api.spotify.com/v1/audio-analysis/6O5w...               261480
# 30  https://api.spotify.com/v1/audio-analysis/2oiJ...               423693
# 31  https://api.spotify.com/v1/audio-analysis/7vQN...               314667
# 32  https://api.spotify.com/v1/audio-analysis/489f...               264600
# 33  https://api.spotify.com/v1/audio-analysis/6FOH...               392573
# 34  https://api.spotify.com/v1/audio-analysis/4uxr...               273693
# 35  https://api.spotify.com/v1/audio-analysis/16KX...               330733
# 36  https://api.spotify.com/v1/audio-analysis/715b...              1026853
# 37  https://api.spotify.com/v1/audio-analysis/3z7d...               251880
# 38  https://api.spotify.com/v1/audio-analysis/1Vof...               193853
# 39  https://api.spotify.com/v1/audio-analysis/0KE7...               295493
# 40  https://api.spotify.com/v1/audio-analysis/6vbR...               467307
# 41  https://api.spotify.com/v1/audio-analysis/0YFt...               233760
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               3
# 9               3
# 10              4
# 11              3
# 12              4
# 13              4
# 14              4
# 15              3
# 16              4
# 17              4
# 18              4
# 19              4
# 20              4
# 21              4
# 22              3
# 23              4
# 24              4
# 25              4
# 26              4
# 27              4
# 28              4
# 29              4
# 30              4
# 31              4
# 32              3
# 33              4
# 34              4
# 35              4
# 36              4
# 37              4
# 38              3
# 39              4
# 40              4
# 41              4
#
# [42 rows x 55 columns]
