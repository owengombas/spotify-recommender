# %%
import pandas as pd
from lib import spoti
from constants import data_path, users_list
import os

# %%
[u.get_auth_url() for u in users_list.USERS]
# Out:
# ['https://accounts.spotify.com/authorize?client_id=a75393ab40f14735bc524677cb4ce3b7&response_type=code&redirect_uri=https%3A%2F%2Fgithub.com%2Fowengombas&scope=user-library-read+user-read-currently-playing+user-read-playback-state+playlist-read-collaborative+user-top-read+user-read-recently-played+user-library-read+user-read-email+']

# %%
[u.log_user() for u in users_list.USERS]
# Out:
# [None]

# %%
USERS_DF = []
for user in users_list.USERS:
    user_top_tracks_medium_term = user.top_tracks(limit=500, offset=0, time_range="medium_term")
    user_top_tracks_short_term = user.top_tracks(limit=500, offset=0, time_range="short_term")
    user_top_tracks_long_term = user.top_tracks(limit=500, offset=0, time_range="long_term")
    user_top_tracks_medium_term["time_range"] = "medium_term"
    user_top_tracks_short_term["time_range"] = "short_term"
    user_top_tracks_long_term["time_range"] = "long_term"
    user_top_tracks: pd.DataFrame = pd.concat([user_top_tracks_medium_term, user_top_tracks_short_term, user_top_tracks_long_term])
    user_top_tracks.to_json(os.path.join(data_path.DATA_PATH, f"{user.username}_top_tracks.json"), orient="records")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:559, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     551 response = self._session.post(
#     552     self.OAUTH_TOKEN_URL,
#     553     data=payload,
#    (...)
#     557     timeout=self.requests_timeout,
#     558 )
# --> 559 response.raise_for_status()
#     560 token_info = response.json()
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# /Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> USERS_DF = []
#       <a href='vscode-notebook-cell:/Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> for user in USERS:
# ----> <a href='vscode-notebook-cell:/Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     user_top_tracks_medium_term = user.top_tracks(limit=500, offset=0, time_range="medium_term")
#       <a href='vscode-notebook-cell:/Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     user_top_tracks_short_term = user.top_tracks(limit=500, offset=0, time_range="short_term")
#       <a href='vscode-notebook-cell:/Users/owen/local/unibe/ml/spotify-recommender/retrieve_top_tracks.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     user_top_tracks_long_term = user.top_tracks(limit=500, offset=0, time_range="long_term")
#
# File ~/local/unibe/ml/spotify-recommender/lib/spoti.py:143, in SpotiUser.top_tracks(self, limit, offset, time_range, wait_seconds)
#     136 def top_tracks(
#     137     self,
#     138     limit: int = 20,
#    (...)
#     141     wait_seconds: float = 2.0,
#     142 ) -> pd.DataFrame:
# --> 143     results = self.sp.current_user_top_tracks(
#     144         limit=limit, offset=offset, time_range=time_range
#     145     )
#     146     result_df = pd.DataFrame(results["items"])
#     147     result_df = self._preprocess_artists(result_df)
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/client.py:1482, in Spotify.current_user_top_tracks(self, limit, offset, time_range)
#    1471 def current_user_top_tracks(
#    1472     self, limit=20, offset=0, time_range="medium_term"
#    1473 ):
#    1474     """ Get the current user's top tracks
#    1475
#    1476         Parameters:
#    (...)
#    1480               Valid-values: short_term, medium_term, long_term
#    1481     """
# -> 1482     return self._get(
#    1483         "me/top/tracks", time_range=time_range, limit=limit, offset=offset
#    1484     )
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:565, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     563     return token_info if as_dict else token_info["access_token"]
#     564 except requests.exceptions.HTTPError as http_error:
# --> 565     self._handle_oauth_error(http_error)
#
# File ~/local/unibe/ml/spotify-recommender/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:146, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     143     error = response.text or None
#     144     error_description = None
# --> 146 raise SpotifyOauthError(
#     147     'error: {0}, error_description: {1}'.format(
#     148         error, error_description
#     149     ),
#     150     error=error,
#     151     error_description=error_description
#     152 )
#
# SpotifyOauthError: error: invalid_grant, error_description: Authorization code expired
